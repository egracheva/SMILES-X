# %%
import pandas as pd

from SMILESX import token, interpret, embedvisual
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Definition of data

# %%
validation_data_dir = "./validation_data/"

# %%
extension = '.csv'

# %%
data_name = 'FreeSolv' # FreeSolv, ESOL, Lipophilicity
prop_tag = ''

# %%
if data_name == 'FreeSolv':
    data_filename = 'FreeSolv_SAMPL'
    prop_tag = 'expt'
elif data_name == 'ESOL':
    data_filename = 'ESOL_delaney-processed'
    prop_tag = 'measured log solubility in mols per litre'
elif data_name == 'Lipophilicity':
    data_filename = 'Lipophilicity'
    prop_tag = 'exp'
else:
    data_filename = data_name
    prop_tag = prop_tag

# %%
sol_data = pd.read_csv(validation_data_dir+data_filename+extension)

# %%
sol_data.head(3)
# Out:
#    Unnamed: 0                             iupac                  smiles  \
# 0           0  4-methoxy-N,N-dimethyl-benzamide  COc1ccc(C(=O)N(C)C)cc1
# 1           1          methanesulfonyl chloride            CS(=O)(=O)Cl
# 2           2                 3-methylbut-1-ene                C=CC(C)C
#
#     expt   calc
# 0 -11.01 -9.625
# 1  -4.87 -6.219
# 2   1.83  2.452

# %%
sol_data = sol_data[['smiles',prop_tag]]

# %%
sol_data.head()
# Out:
#                    smiles   expt
# 0  COc1ccc(C(=O)N(C)C)cc1 -11.01
# 1            CS(=O)(=O)Cl  -4.87
# 2                C=CC(C)C   1.83
# 3              CCc1cnccn1  -5.45
# 4                CCCCCCCO  -4.21

# %%
sol_data.shape
# Out:
# (642, 2)

# %% [markdown]
# #### Embedding Visualization

# %%
embedvisual.Embedding_Vis(data=sol_data, 
                          data_name=data_name, 
                          data_units='', 
                          k_fold_number = 1,
                          k_fold_index = 0,
                          augmentation = True, 
                          outdir = "./data/", 
                          affinity_propn = True)
# Out:
# ***SMILES_X for embedding visualization starts...***
#
#
# ******
# ***Fold #773630 initiated...***
# ******
# ***Sampling and splitting of the dataset.***
#
# Scaler: RobustScaler(copy=True, quantile_range=(5.0, 95.0), with_centering=True,
#              with_scaling=True)
# Train/valid/test splits: 0.80/0.10/0.10
#
#
# ***Data augmentation.***
#
# Enumerated SMILES:
# 	Training set: 4283
# 	Validation set: 499
# 	Test set: 573
#
# ***Tokenization of SMILES.***
#
# Examples of tokenized SMILES from a training set:
# [[' ', 'C', 'c', '1', 'c', 'c', 'c', 'c', 'n', '1', ' '], [' ', 'c', '1', '(', 'C', ')', 'c', 'c', 'c', 'c', 'n', '1', ' '], [' ', 'c', '1', 'c', 'c', 'c', 'n', 'c', '1', 'C', ' '], [' ', 'c', '1', 'c', 'c', 'n', 'c', '(', 'C', ')', 'c', '1', ' '], [' ', 'c', '1', 'c', 'n', 'c', '(', 'C', ')', 'c', 'c', '1', ' ']]
#
# ['-', 'Br', '[O-]', 'N', '#', '1', ')', '[C@]', 'F', '[S+2]', '3', '[C@@]', '[C@@H]', '(', 'Cl', 'O', '[nH]', 'P', '=', 's', '/', ' ', 'n', 'C', '[C@H]', 'c', '4', 'I', '2', 'S', '\\', '[N+]']
# Number of tokens only present in a training set: 32
#
# Full vocabulary: ['pad', 'unk', '[C@@H]', 'P', 'N', '[C@H]', '#', '-', ' ', '2', 'Br', '[S+2]', '(', '/', '3', '=', '\\', '1', 'I', 'Cl', 'n', 's', 'O', 'S', '[C@@]', 'C', ')', '[O-]', '[C@]', 'c', '[N+]', '[nH]', '5', 'F', '4']
# Of size: 35
#
# Maximum length of tokenized SMILES: 50 tokens (termination spaces included)
#
# WARNING:tensorflow:From /home/egracheva/miniconda3/envs/python3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/egracheva/miniconda3/envs/python3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Chosen model summary:
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 51)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 51, 256)           8960
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 51, 16)            17024
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 51, 64)            1088
# _________________________________________________________________
# attention_m_1 (AttentionM)   (None, 64)                115
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 27,252
# Trainable params: 27,252
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ***Embedding of the individual tokens from the chosen model.***

# %% [markdown]
# #### Find tokens in SMILES

# %%
token.TokensFinder(data=sol_data, 
                   data_name=data_name, 
                   data_units='', 
                   k_fold_number = 1,
                   k_fold_index = 0,
                   augmentation = True, 
                   token_tofind = '[nH]', 
                   verbose = 0)
# Out:
# ***SMILES_X token's finder starts...***
#
#
# ******
# ***Fold #773630 initiated...***
# ******
# ***Sampling and splitting of the dataset.***
#
# Scaler: RobustScaler(copy=True, quantile_range=(5.0, 95.0), with_centering=True,
#              with_scaling=True)
# Train/valid/test splits: 0.80/0.10/0.10
#
#
# ***Data augmentation.***
#
# Enumerated SMILES:
# 	Training set: 4283
# 	Validation set: 499
# 	Test set: 573
#
# ***Tokenization of SMILES.***
#
# Examples of tokenized SMILES from a training set:
# [[' ', 'C', 'c', '1', 'c', 'c', 'c', 'c', 'n', '1', ' '], [' ', 'c', '1', '(', 'C', ')', 'c', 'c', 'c', 'c', 'n', '1', ' '], [' ', 'c', '1', 'c', 'c', 'c', 'n', 'c', '1', 'C', ' '], [' ', 'c', '1', 'c', 'c', 'n', 'c', '(', 'C', ')', 'c', '1', ' '], [' ', 'c', '1', 'c', 'n', 'c', '(', 'C', ')', 'c', 'c', '1', ' ']]
#
# The finder is processing the search...
#
# 105 SMILES found with [nH] token in the training set.

# %% [markdown]
# #### SMILES inference interpretation

# %%
interpret.Interpretation(data=sol_data, 
                         data_name=data_name, 
                         data_units='', 
                         k_fold_number = 1,
                         k_fold_index = 0,
                         augmentation = True, 
                         outdir = "./data/", 
                         smiles_toviz = 'ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@H]4C[C@H]([C@@H]5O[C@@H]54)[C@H]3[C@@]1(Cl)C2(Cl)Cl', 
                         font_size = 15, 
                         font_rotation = 'vertical')
# Out:
# ***SMILES_X Interpreter starts...***
#
#
# ******
# ***Fold #773630 initiated...***
# ******
# ***Sampling and splitting of the dataset.***
#
# Scaler: RobustScaler(copy=True, quantile_range=(5.0, 95.0), with_centering=True,
#              with_scaling=True)
# Train/valid/test splits: 0.80/0.10/0.10
#
#
# ***Data augmentation.***
#
# Enumerated SMILES:
# 	Training set: 4283
# 	Validation set: 499
# 	Test set: 573
#
# ***Tokenization of SMILES.***
#
# Examples of tokenized SMILES from a training set:
# [[' ', 'C', 'c', '1', 'c', 'c', 'c', 'c', 'n', '1', ' '], [' ', 'c', '1', '(', 'C', ')', 'c', 'c', 'c', 'c', 'n', '1', ' '], [' ', 'c', '1', 'c', 'c', 'c', 'n', 'c', '1', 'C', ' '], [' ', 'c', '1', 'c', 'c', 'n', 'c', '(', 'C', ')', 'c', '1', ' '], [' ', 'c', '1', 'c', 'n', 'c', '(', 'C', ')', 'c', 'c', '1', ' ']]
#
# ['-', 'Br', '[O-]', 'N', '#', '1', ')', '[C@]', 'F', '[S+2]', '3', '[C@@]', '[C@@H]', '(', 'Cl', 'O', '[nH]', 'P', '=', 's', '/', ' ', 'n', 'C', '[C@H]', 'c', '4', 'I', '2', 'S', '\\', '[N+]']
# Number of tokens only present in a training set: 32
#
# Full vocabulary: ['pad', 'unk', '[C@@H]', 'P', 'N', '[C@H]', '#', '-', ' ', '2', 'Br', '[S+2]', '(', '/', '3', '=', '\\', '1', 'I', 'Cl', 'n', 's', 'O', 'S', '[C@@]', 'C', ')', '[O-]', '[C@]', 'c', '[N+]', '[nH]', '5', 'F', '4']
# Of size: 35
#
# Maximum length of tokenized SMILES: 50 tokens
#
# Best model summary:
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 51)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 51, 256)           8960
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 51, 16)            17024
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 51, 64)            1088
# _________________________________________________________________
# attention_m_3 (AttentionM)   (None, 64)                115
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 27,252
# Trainable params: 27,252
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ***Interpretation from the best model.***
#
# True value: -4.82 Predicted: -5.87
